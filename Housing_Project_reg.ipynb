# %% [markdown]
# <a href="https://colab.research.google.com/github/amnarafique/Django-another/blob/master/Housing_Project_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/content/Chapter 2 - housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import matplotlib.pyplot as plt
df.hist(bins=30,figsize=(20,15))
plt.show()

# %%
df["median_income"] = pd.cut(df['median_income'],
                             bins=[0.,1.5,3.,4.5,6.],
                             labels=[1,2,3,4,5])
df["median_income"].hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-48b1cdb5372e> in <cell line: 1>()
# ----> 1 df["median_income"] = pd.cut(df['median_income'],
#       2                              bins=[0.,1.5,3.,4.5,6.,np.inf],
#       3                              labels=[1,2,3,4,5,6])
#       4 df["median_income"].hist()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     291             raise ValueError("bins must increase monotonically.")
#     292
# --> 293     fac, bins = _bins_to_cuts(
#     294         x,
#     295         bins,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     452         else:
# ...
